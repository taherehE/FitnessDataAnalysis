# %%
import numpy as np
from numpy import count_nonzero
import pyreadstat
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import scatterplot as scatter
from scipy.sparse import csr_matrix
from sklearn.feature_selection import VarianceThreshold
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import NMF
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import SpectralClustering
from sklearn.cluster import Birch
from sklearn.cluster import DBSCAN
from sklearn.cluster import AffinityPropagation
from sklearn.cluster import MeanShift
from sklearn.cluster import AgglomerativeClustering

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn import metrics
#from sklearn.model_selection import cross_val_score
#import sklearn.metrics.scorer as scorer


#reading data from file

#df,meta=pyreadstat.read_sav("C:/Users/APPLE/Desktop/Folders/sana thesis/SHAHNAZ-meysam-tekvando.sav")
df=pd.read_excel("C:/Users/APPLE/Desktop/Folders/sana thesis/SHAHNAZ-meysam-tekvandolabelmodified.xls")

#preprocessing operations such as converting Nan values to zero,
#converting fields without value to zero,
#removing ID,fisrtname, and familyname columns from dataset

features_name=df.columns
data=np.array(df)
df=pd.DataFrame(data=data,columns=features_name)
df=df.drop(['firstname','familyname','year'],axis=1)

# keep only women samples
df1=df
for l in range(2559):
    if (df1.iloc[l,0]==1.0):
        df=df.drop([l])    

true_labels=df.iloc[:,-1]
df=df.drop(['label','gender'],axis=1)
features_name=df.columns




for l in range(len(df.columns)):
    nanvalue_ratio=(df.iloc[:,l].isna().sum()/float( len(df)))*100
    zerovalue_ratio=100-((count_nonzero(df.iloc[:,l]) / float(len(df)))*100)
    realnanvalue_ratio=nanvalue_ratio+zerovalue_ratio
    print('percentage of nan values of feature %s is %0.3f' %(features_name[l], realnanvalue_ratio))
    print('maximum value of feature %s is %s' %(features_name[l],df.iloc[:,l].max()))
    print('minimum value of feature %s is %s' %(features_name[l],df.iloc[:,l].min()))
    print("............................................................................")
# Out:
# percentage of nan values of feature age is 13.782
# maximum value of feature age is 44.0
# minimum value of feature age is 0.0
# ............................................................................
# percentage of nan values of feature weight is 8.205
# maximum value of feature weight is 111.0
# minimum value of feature weight is 30.0
# ............................................................................
# percentage of nan values of feature height is 15.641
# maximum value of feature height is 200.0
# minimum value of feature height is 0.0
# ............................................................................
# percentage of nan values of feature satHeight is 24.295
# maximum value of feature satHeight is 109.0
# minimum value of feature satHeight is 0.0
# ............................................................................
# percentage of nan values of feature ArmSpan is 56.346
# maximum value of feature ArmSpan is 218.0
# minimum value of feature ArmSpan is 0.0
# ............................................................................
# percentage of nan values of feature fat is 37.115
# maximum value of feature fat is 52.0
# minimum value of feature fat is 0.0
# ............................................................................
# percentage of nan values of feature Vo2Max is 36.859
# maximum value of feature Vo2Max is 68.8
# minimum value of feature Vo2Max is 0.0
# ............................................................................
# percentage of nan values of feature HR is 48.077
# maximum value of feature HR is 198.0
# minimum value of feature HR is 0.0
# ............................................................................
# percentage of nan values of feature Concani is 99.231
# maximum value of feature Concani is 6.3
# minimum value of feature Concani is 5.24
# ............................................................................
# percentage of nan values of feature burus is 100.000
# maximum value of feature burus is nan
# minimum value of feature burus is nan
# ............................................................................
# percentage of nan values of feature fortyYard is 7.756
# maximum value of feature fortyYard is 7.35
# minimum value of feature fortyYard is 0.0
# ............................................................................
# percentage of nan values of feature WingtePP is 87.372
# maximum value of feature WingtePP is 599.0
# minimum value of feature WingtePP is 6.5
# ............................................................................
# percentage of nan values of feature wingetAP is 97.372
# maximum value of feature wingetAP is 9.71
# minimum value of feature wingetAP is 3.57
# ............................................................................
# percentage of nan values of feature ricaveri is 100.000
# maximum value of feature ricaveri is nan
# minimum value of feature ricaveri is nan
# ............................................................................
# percentage of nan values of feature oneMayl is 100.000
# maximum value of feature oneMayl is nan
# minimum value of feature oneMayl is nan
# ............................................................................
# percentage of nan values of feature ergoJump5S is 13.013
# maximum value of feature ergoJump5S is 80.0
# minimum value of feature ergoJump5S is 0.0
# ............................................................................
# percentage of nan values of feature highJump is 10.321
# maximum value of feature highJump is 87.0
# minimum value of feature highJump is 0.0
# ............................................................................
# percentage of nan values of feature pareshTool is 99.487
# maximum value of feature pareshTool is 285.0
# minimum value of feature pareshTool is 189.0
# ............................................................................
# percentage of nan values of feature ghodratPanjeh is 72.179
# maximum value of feature ghodratPanjeh is 440.0
# minimum value of feature ghodratPanjeh is 0.0
# ............................................................................
# percentage of nan values of feature joftDoTaraf is 27.372
# maximum value of feature joftDoTaraf is 190.0
# minimum value of feature joftDoTaraf is 0.0
# ............................................................................
# percentage of nan values of feature derazNeshast is 26.346
# maximum value of feature derazNeshast is 93.0
# minimum value of feature derazNeshast is 0.0
# ............................................................................
# percentage of nan values of feature barfix is 81.538
# maximum value of feature barfix is 67.0
# minimum value of feature barfix is 0.0
# ............................................................................
# percentage of nan values of feature chaharDarNoh is 66.090
# maximum value of feature chaharDarNoh is 20.48
# minimum value of feature chaharDarNoh is 0.0
# ............................................................................
# percentage of nan values of feature marpych is 43.077
# maximum value of feature marpych is 23.88
# minimum value of feature marpych is 0.0
# ............................................................................
# percentage of nan values of feature jaheshJanebi is 99.872
# maximum value of feature jaheshJanebi is 15.8
# minimum value of feature jaheshJanebi is 14.6
# ............................................................................
# percentage of nan values of feature FlexibleTanehBeJeloo is 8.013
# maximum value of feature FlexibleTanehBeJeloo is 64.0
# minimum value of feature FlexibleTanehBeJeloo is 0.0
# ............................................................................
# percentage of nan values of feature FlexibleTanehBePosht is 60.449
# maximum value of feature FlexibleTanehBePosht is 560.0
# minimum value of feature FlexibleTanehBePosht is 0.0
# ............................................................................
# percentage of nan values of feature FlexibleShoulder is 77.115
# maximum value of feature FlexibleShoulder is 1.93
# minimum value of feature FlexibleShoulder is 0.16
# ............................................................................
# percentage of nan values of feature FlexibleRan is 56.987
# maximum value of feature FlexibleRan is 0.84
# minimum value of feature FlexibleRan is 0.0
# ............................................................................
# percentage of nan values of feature RtSight is 17.756
# maximum value of feature RtSight is 790.0
# minimum value of feature RtSight is 0.0
# ............................................................................
# percentage of nan values of feature RTshenidari is 99.231
# maximum value of feature RTshenidari is 460.0
# minimum value of feature RTshenidari is 342.0
# ............................................................................
# percentage of nan values of feature tawanBiHavazi is 98.013
# maximum value of feature tawanBiHavazi is 50.0
# minimum value of feature tawanBiHavazi is 32.0
# ............................................................................
# percentage of nan values of feature biHAVA1609 is 87.628
# maximum value of feature biHAVA1609 is 8.33
# minimum value of feature biHAVA1609 is 5.14
# ............................................................................
# percentage of nan values of feature Do1600 is 100.000
# maximum value of feature Do1600 is nan
# minimum value of feature Do1600 is nan
# ............................................................................
# percentage of nan values of feature yekMayl is 100.000
# maximum value of feature yekMayl is nan
# minimum value of feature yekMayl is nan
# ............................................................................
# percentage of nan values of feature metr540 is 98.077
# maximum value of feature metr540 is 2.02
# minimum value of feature metr540 is 1.32
# ............................................................................
# percentage of nan values of feature taadol is 98.333
# maximum value of feature taadol is 14.4
# minimum value of feature taadol is 3.1
# ............................................................................

# %%
df=df.drop(['Concani','burus','wingetAP','WingtePP','ricaveri','oneMayl','pareshTool','ghodratPanjeh','barfix','jaheshJanebi',
            'FlexibleShoulder','RTshenidari','tawanBiHavazi','biHAVA1609','Do1600','yekMayl',
            'metr540','taadol'],axis=1)
features_name=df.columns

# %%
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import KNNImputer
from sklearn.impute import MissingIndicator
from sklearn.impute import SimpleImputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import ExtraTreesRegressor

data=np.array(df)
data=data.astype('float')
data[data==0.0]=np.nan
df=pd.DataFrame(data=data,columns=features_name)

strategy=('mean','median')
simpleimputer=SimpleImputer(missing_values=np.nan, strategy=strategy[1])
data1=simpleimputer.fit_transform(df)
#df1=pd.DataFrame(data=data1,columns=features_name)
#simpleimputer=SimpleImputer(missing_values=0.0, strategy=strategy[0])
#data1=simpleimputer.fit_transform(df1)


knnimputer=KNNImputer(missing_values=np.nan)
data2=knnimputer.fit_transform(df)
#df2=pd.DataFrame(data=data2,columns=features_name)
#knnimputer=KNNImputer(missing_values=0.0)
#data2=knnimputer.fit_transform(df2)

estimators=[BayesianRidge(),
            DecisionTreeRegressor(max_features='sqrt',random_state=0),
            ExtraTreesRegressor(n_estimators=10, random_state=0),
            KNeighborsRegressor(n_neighbors=15)
           ]

iterativeimputer=IterativeImputer(missing_values=np.nan, random_state=0, estimator=estimators[0], n_nearest_features=5)
data3=iterativeimputer.fit_transform(df)
#df3=pd.DataFrame(data=data3,columns=features_name)
#iterativeimputer=IterativeImputer(missing_values=0.0, random_state=0, estimator=estimators[0], n_nearest_features=5)
#data3=iterativeimputer.fit_transform(df3)
# Out:
# C:\Users\APPLE\AppData\Roaming\Python\Python37\site-packages\sklearn\impute\_iterative.py:638: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   " reached.", ConvergenceWarning)

# %%
df=pd.DataFrame(data=data3,columns=features_name)
sns.distplot(df.iloc[:,18],axlabel=features_name[18])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
for l in range(len(df.columns)):
    print('maximum value of feature %s is %s' %(features_name[l],df.iloc[:,l].max()))
    print('minimum value of feature %s is %s' %(features_name[l],df.iloc[:,l].min()))
    print("............................................................................")
# Out:
# maximum value of feature age is 44.0
# minimum value of feature age is 12.0
# ............................................................................
# maximum value of feature weight is 111.0
# minimum value of feature weight is 30.0
# ............................................................................
# maximum value of feature height is 200.0
# minimum value of feature height is 111.0
# ............................................................................
# maximum value of feature satHeight is 109.0
# minimum value of feature satHeight is 47.0
# ............................................................................
# maximum value of feature ArmSpan is 218.0
# minimum value of feature ArmSpan is 82.0
# ............................................................................
# maximum value of feature fat is 52.0
# minimum value of feature fat is 1.8
# ............................................................................
# maximum value of feature Vo2Max is 68.8
# minimum value of feature Vo2Max is 4.0
# ............................................................................
# maximum value of feature HR is 198.0
# minimum value of feature HR is 104.0
# ............................................................................
# maximum value of feature fortyYard is 7.35
# minimum value of feature fortyYard is 4.09
# ............................................................................
# maximum value of feature ergoJump5S is 80.0
# minimum value of feature ergoJump5S is 3.913
# ............................................................................
# maximum value of feature highJump is 87.0
# minimum value of feature highJump is 28.0
# ............................................................................
# maximum value of feature joftDoTaraf is 208.50801496820316
# minimum value of feature joftDoTaraf is 66.8167102051572
# ............................................................................
# maximum value of feature derazNeshast is 93.0
# minimum value of feature derazNeshast is 7.0
# ............................................................................
# maximum value of feature chaharDarNoh is 20.48
# minimum value of feature chaharDarNoh is 1.28
# ............................................................................
# maximum value of feature marpych is 23.88
# minimum value of feature marpych is 10.31
# ............................................................................
# maximum value of feature FlexibleTanehBeJeloo is 64.0
# minimum value of feature FlexibleTanehBeJeloo is 9.0
# ............................................................................
# maximum value of feature FlexibleTanehBePosht is 560.0
# minimum value of feature FlexibleTanehBePosht is 36.0
# ............................................................................
# maximum value of feature FlexibleRan is 0.84
# minimum value of feature FlexibleRan is 0.01
# ............................................................................
# maximum value of feature RtSight is 790.0
# minimum value of feature RtSight is 180.0
# ............................................................................

# %%
#removing correlated features

correlated_features=set()
correlation_matrix=df.corr()

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i,j])>0.5:
            colname=correlation_matrix.columns[i]
            correlated_features.add(colname)
            
df=df.drop(labels=correlated_features,axis=1)    
features_name=df.columns
data=np.array(df)

# %%
correlated_features
# Out:
# {'ArmSpan',
#  'RtSight',
#  'derazNeshast',
#  'height',
#  'highJump',
#  'joftDoTaraf',
#  'marpych',
#  'satHeight'}

# %%
#performing standardScaler as preprocessing

scaler=StandardScaler(with_mean=False)
data_scaled=scaler.fit_transform(data2)
df=pd.DataFrame(data=data_scaled,columns=features_name)

df.to_excel("C:/Users/APPLE/Desktop/Folders/sana thesis/men-tekvando.xls")

# %%
#keep 20% of dataset for test
df_train,df_test=train_test_split(df,test_size=0.2)
data=np.array(df_train)

# %%
for l in range(len(df.columns)):
    print('maximum value of feature %s is %s' %(features_name[l],df.iloc[:,l].max()))
    print('minimum value of feature %s is %s' %(features_name[l],df.iloc[:,l].min()))
    print("............................................................................")
# Out:
# maximum value of feature age is 9.47621032664288
# minimum value of feature age is 2.584420998175331
# ............................................................................
# maximum value of feature weight is 9.089433555292239
# minimum value of feature weight is 0.4585660172039327
# ............................................................................
# maximum value of feature fat is 13.03294035647511
# minimum value of feature fat is 0.45114024310875384
# ............................................................................
# maximum value of feature Vo2Max is 6.6575848489382645
# minimum value of feature Vo2Max is 0.3870688865661782
# ............................................................................
# maximum value of feature HR is 27.034650463546637
# minimum value of feature HR is 14.200018425297223
# ............................................................................
# maximum value of feature fortyYard is 18.80452641939096
# minimum value of feature fortyYard is 10.464015381674697
# ............................................................................
# maximum value of feature ergoJump5S is 8.146013000565725
# minimum value of feature ergoJump5S is 0.398441860890171
# ............................................................................
# maximum value of feature chaharDarNoh is 19.79573565489992
# minimum value of feature chaharDarNoh is 1.237233478431245
# ............................................................................
# maximum value of feature FlexibleTanehBeJeloo is 9.992463831624896
# minimum value of feature FlexibleTanehBeJeloo is 1.4051902263222509
# ............................................................................
# maximum value of feature FlexibleTanehBePosht is 15.047379068945425
# minimum value of feature FlexibleTanehBePosht is 0.967331511575063
# ............................................................................
# maximum value of feature FlexibleRan is 14.919666186235977
# minimum value of feature FlexibleRan is 0.1776150736456664
# ............................................................................
